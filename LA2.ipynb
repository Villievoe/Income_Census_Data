# %% [markdown]
# This dataset represents the data of Income and Census of Adults from different regions of the world with different occupations. The dataset has been taken from Kaggle. The goal of the analysis is to find the income statistics based on age,gender, race, region, education, etc.
#
# The data is stored in the "adult_data.csv" file.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# The first few data entries are as follows:

# %%
df = pd.read_csv("/home/vinutna/Documents/Data Science Class/adult_data.csv")
print(df.head())
# Out:
#    age          workclass  finalweight   education  Edu-num Marital-status  \
# 0   39          State-gov        77516   Bachelors       13          Unmar
# 1   50   Self-emp-not-inc        83311   Bachelors       13         Spouse
# 2   38            Private       215646     HS-grad        9       Divorced
# 3   53            Private       234721        11th        7         Spouse
# 4   28            Private       338409   Bachelors       13         Spouse
#
#   occupation    relationship    race      sex  Capital-gain  Capital-loss  \
# 0       Admn   Not-in-family   White     Male          2174             0
# 1       Mngr         Husband   White     Male             0             0
# 2      Clean   Not-in-family   White     Male             0             0
# 3      Clean         Husband   Black     Male             0             0
# 4       Prof            Wife   Black   Female             0             0
#
#    Hrs-per-week  Native-country Income-range
# 0            40   United-States        <=50K
# 1            13   United-States        <=50K
# 2            40   United-States        <=50K
# 3            40   United-States        <=50K
# 4            40            Cuba        <=50K

# %% [markdown]
# The description of the columns of the dataset are as follows:

# %%
print(df.describe())
# Out:
#                 age   finalweight       Edu-num  Capital-gain  Capital-loss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        Hrs-per-week
# count  32561.000000
# mean      40.437456
# std       12.347429
# min        1.000000
# 25%       40.000000
# 50%       40.000000
# 75%       45.000000
# max       99.000000

# %% [markdown]
# Finding the mean of number of hours per week that an individual of particular occupation works for

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv("/home/vinutna/Documents/Data Science Class/adult_data.csv")
ageTime = df.groupby("occupation").agg({"Hrs-per-week": "mean"})
plotAgeTime = ageTime.plot(color = "#ab1234")

# %% [markdown]
# Finding the maximum pay for each education level and thereby who earns the most

# %%
import matplotlib.pyplot as pplt

eduGain = df.groupby("education").agg({"finalweight": "max"})
plotEduGain = eduGain.plot.pie(subplots = "True",legend=False)

centre_circle = pplt.Circle((0,0),0.70,fc='white')
fig = pplt.gcf()
fig.gca().add_artist(centre_circle)

pplt.tight_layout()
pplt.show()

# %% [markdown]
# Finding the mean income of adults of each country.

# %%
regIncome = df.groupby("Native-country").agg({"finalweight": "mean"})
plotRegIncome = regIncome.plot(kind = "bar", width = 0.4, facecolor = np.random.rand(3,))

# %% [markdown]
# Finding the capital gain depending on the relationship to the employee.

# %%
relWeight = df.groupby("relationship").agg({"Capital-gain" : "max"})
plotRelWeight = relWeight.plot(kind = "bar", facecolor = np.random.rand(3,))

# %% [markdown]
# Classifying pay based on Race

# %%
import seaborn as sns
import pandas as pd
import matplotlib as plt
import numpy as np

df = pd.read_csv("/home/vinutna/Documents/Data Science Class/adult_data.csv")
sns.set_style("whitegrid")
sns.stripplot(x="race",y="finalweight",data=df,palette=sns.mpl_palette("Set1",5))
sns.despine()

# %% [markdown]
# Identifying the range of income based on the number of hours worked per week

# %%
sns.set_style("whitegrid")
sns.boxplot(x="Income-range",y="Hrs-per-week",data=df)
sns.despine()

# %% [markdown]
# Finding the age of employees based on Gender

# %%
sns.set_style("whitegrid")
sns.violinplot(x=df['sex'],y=df['age'],palette=sns.mpl_palette("Set3",2))
sns.despine()

# %% [markdown]
# Finding the capital loss of different working classes

# %%
sns.pointplot(x=df['Capital-loss'],y=df['workclass'],palette="bright")
sns.despine()

# %% [markdown]
# Finding capital loss based on age.

# %%
sns.lineplot(x=df['Capital-loss'],y=df['age'],color="violet",data=df)
sns.despine()
